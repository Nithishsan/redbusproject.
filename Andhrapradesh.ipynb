# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver import ActionChains
import time
import mysql.connector
import pandas as pd
# Connect Database
db_connection = mysql.connector.connect(
    host="localhost",
    user="root",
    password="1234",
    database="redbus"
)
cursor = db_connection.cursor()
print("Database connected Successfully")

# SQL to create table
create_table_query = """
CREATE TABLE IF NOT EXISTS BusDetails(
    id INT PRIMARY KEY AUTO_INCREMENT,
    state VARCHAR(100) DEFAULT 'Andhra Pradesh',
    route_name VARCHAR(255),
    route_link VARCHAR(255),
    bus_name VARCHAR(255),
    bus_type VARCHAR(255),
    departing_time TEXT,
    duration VARCHAR(50),
    reaching_time TEXT,
    star_rating TEXT,
    price VARCHAR(50),
    seat_availability TEXT
);
"""
cursor.execute(create_table_query)
print("Table created successfully")

# Initialize the WebDriver
driver = webdriver.Chrome()
driver.implicitly_wait(5)
wait = WebDriverWait(driver, 10)

# Navigate to the upsrtc Bus Routes page
driver.get("https://www.redbus.in/online-booking/apsrtc/?utm_source=rtchometile")
driver.maximize_window()
time.sleep(2)
route_data = []
# Function to scrape route data
def scrape_page():
    routescontainer = wait.until(EC.presence_of_all_elements_located((By.XPATH, '//*[@id="root"]/div/div[4]/div[2]/div[1]/a')))
      
    for route in routescontainer:
        route_data.append({
            'Route Name': route.text,
            'Route Link': route.get_attribute('href')
        })
    return route_data  # Return the scraped data

# Pagination to collect routes from multiple pages
for page_number in range(1, 6):
    try:
        pagination_container = wait.until(EC.presence_of_element_located((By.XPATH, '//*[@id="root"]/div/div[4]/div[12]')))
        next_page_button = pagination_container.find_element(By.XPATH, f'.//div[contains(@class,"DC_117_pageTabs") and text()="{page_number + 1}"]')

        actions = ActionChains(driver)
        actions.move_to_element(next_page_button).perform()
        next_page_button.click()
        time.sleep(1)

        wait.until(EC.text_to_be_present_in_element((By.XPATH, f'.//div[contains(@class,"DC_117_pageTabs DC_117_pageActive")]'), str(page_number + 1)))
        time.sleep(2)

        scrape_page()

    except Exception as e:
        print(e)
        break


# Function to scrape bus details
def collect_bus_details():
    alldetails = []
    for data in route_data:
        link = data['Route Link']
        route_name = data['Route Name']
        try:
            driver.get(link)
            time.sleep(2)
            try:
                view_buses_buttons = wait.until(EC.presence_of_all_elements_located((By.XPATH, "//div[@class='button']")))
                for button in view_buses_buttons:
                    wait.until(EC.element_to_be_clickable(button)).click()
                    time.sleep(3)  # Wait for the buses to load
            except Exception as e:
                print(f"Error clicking 'View Buses' button for {route_name}: {e}")

            bus_containers = wait.until(EC.presence_of_all_elements_located((By.XPATH, "//div[contains(@class, 'clearfix bus-item')]")))
            for bus_container in bus_containers:
                try:
                    busname = bus_container.find_element(By.XPATH, ".//div[@class='travels lh-24 f-bold d-color']").text
                    bustype = bus_container.find_element(By.XPATH, ".//div[@class='bus-type f-12 m-top-16 l-color evBus']").text
                    departuretiming = bus_container.find_element(By.XPATH, ".//div[@class='dp-time f-19 d-color f-bold']").text
                    duration = bus_container.find_element(By.XPATH, ".//div[@class='dur l-color lh-24']").text
                    reachtiming = bus_container.find_element(By.XPATH, ".//div[@class='bp-time f-19 d-color disp-Inline']").text
                    rating = bus_container.find_element(By.XPATH, ".//div[@class='rating-sec lh-24']").text
                    price = bus_container.find_element(By.XPATH, ".//span[contains(@class,'f-19 f-bold') or contains(@class,'f-bold f-19')]").text
                    seat = bus_container.find_element(By.XPATH, ".//div[contains(@class, 'seat-left m-top-30') or contains(@class,'seat-left m-top-16')]").text

                    details = {
                        'State': "Andhrapradesh",
                        'Route Name': route_name,
                        'Route Link': link,
                        'Bus Name': busname,
                        'Bus Type': bustype,
                        'Departing Time': departuretiming,
                        'Duration': duration,
                        'Reaching Time': reachtiming,
                        'Star Rating': rating,
                        'Price': price,
                        'Seat Availability': seat,
                    }
                    # Check if the details already exist in the list
                    if details not in alldetails:
                        print(details)
                        alldetails.append(details)

                        # Insert data into the database
                        insert_query = """
                        INSERT IGNORE INTO BusDetails (state, route_name, route_link, bus_name, bus_type, departing_time, duration, reaching_time, star_rating, price, seat_availability)
                        VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
                        """
                        cursor.execute(insert_query, (
                            details['State'],
                            details['Route Name'],
                            details['Route Link'],
                            details['Bus Name'],
                            details['Bus Type'],
                            details['Departing Time'],
                            details['Duration'],
                            details['Reaching Time'],
                            details['Star Rating'],
                            details['Price'],
                            details['Seat Availability']
                        ))
                        db_connection.commit()
                except Exception as e:
                    print(f"Error scraping bus details for {route_name}: {e}")
        except Exception as e:
            print(f"Error accessing route link {link}: {e}")
    return alldetails

# Main execution


bus_details = collect_bus_details()
print("Collected Bus Details:", bus_details)


df = pd.DataFrame(bus_details)
df.to_csv("Andhrapradesh.csv", index=False)

# Close the WebDriver
driver.quit()

# Close the Database Connection
cursor.close()
db_connection.close()
# Out:
# Database connected Successfully
# Table created successfully
# Message: no such element: Unable to locate element: {"method":"xpath","selector":".//div[contains(@class,"DC_117_pageTabs") and text()="6"]"}
#   (Session info: chrome=132.0.6834.160); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF6859502F5+28725]
# 	(No symbol) [0x00007FF6858B2AE0]
# 	(No symbol) [0x00007FF68574510A]
# 	(No symbol) [0x00007FF6857993D2]
# 	(No symbol) [0x00007FF6857995FC]
# 	(No symbol) [0x00007FF68578C0BC]
# 	(No symbol) [0x00007FF6857BFFEF]
# 	(No symbol) [0x00007FF68578BF86]
# 	(No symbol) [0x00007FF6857C01C0]
# 	(No symbol) [0x00007FF6857E0181]
# 	(No symbol) [0x00007FF6857BFD53]
# 	(No symbol) [0x00007FF68578A0E3]
# 	(No symbol) [0x00007FF68578B471]
# 	GetHandleVerifier [0x00007FF685C7F30D+3366989]
# 	GetHandleVerifier [0x00007FF685C912F0+3440688]
# 	GetHandleVerifier [0x00007FF685C878FD+3401277]
# 	GetHandleVerifier [0x00007FF685A1AAAB+858091]
# 	(No symbol) [0x00007FF6858BE74F]
# 	(No symbol) [0x00007FF6858BA304]
# 	(No symbol) [0x00007FF6858BA49D]
# 	(No symbol) [0x00007FF6858A8B69]
# 	BaseThreadInitThunk [0x00007FFFFD2CE8D7+23]
# 	RtlUserThreadStart [0x00007FFFFE93FBCC+44]
#
# Error clicking 'View Buses' button for Hyderabad to Guntur (Andhra Pradesh): Message: element click intercepted: Element <div class="button">...</div> is not clickable at point (1442, 709). Other element would receive the click: <div class="clearfix row-one ">...</div>
#   (Session info: chrome=132.0.6834.160)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF6859502F5+28725]
# 	(No symbol) [0x00007FF6858B2AE0]
# 	(No symbol) [0x00007FF68574510A]
# 	(No symbol) [0x00007FF6857A10F8]
# 	(No symbol) [0x00007FF68579EB42]
# 	(No symbol) [0x00007FF68579BC51]
# 	(No symbol) [0x00007FF68579ABB1]
# 	(No symbol) [0x00007FF68578C6B4]
# 	(No symbol) [0x00007FF6857BFFAA]
# 	(No symbol) [0x00007FF68578BF86]
# 	(No symbol) [0x00007FF6857C01C0]
# 	(No symbol) [0x00007FF6857E0181]
# 	(No symbol) [0x00007FF6857BFD53]
# 	(No symbol) [0x00007FF68578A0E3]
# 	(No symbol) [0x00007FF68578B471]
# 	GetHandleVerifier [0x00007FF685C7F30D+3366989]
# 	GetHandleVerifier [0x00007FF685C912F0+3440688]
# 	GetHandleVerifier [0x00007FF685C878FD+3401277]
# 	GetHandleVerifier [0x00007FF685A1AAAB+858091]
# 	(No symbol) [0x00007FF6858BE74F]
# 	(No symbol) [0x00007FF6858BA304]
# 	(No symbol) [0x00007FF6858BA49D]
# 	(No symbol) [0x00007FF6858A8B69]
# 	BaseThreadInitThunk [0x00007FFFFD2CE8D7+23]
# 	RtlUserThreadStart [0x00007FFFFE93FBCC+44]
#
# {'State': 'BIHAR', 'Route Name': 'Hyderabad to Guntur (Andhra Pradesh)', 'Route Link': 'https://www.redbus.in/bus-tickets/hyderabad-to-guntur', 'Bus Name': 'APSRTC - 4197', 'Bus Type': 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', 'Departing Time': '10:30', 'Duration': '08h 20m', 'Reaching Time': '18:50', 'Star Rating': '3.5', 'Price': '451', 'Seat Availability': '26 Seats available'}
# {'State': 'BIHAR', 'Route Name': 'Hyderabad to Guntur (Andhra Pradesh)', 'Route Link': 'https://www.redbus.in/bus-tickets/hyderabad-to-guntur', 'Bus Name': 'APSRTC - 4612', 'Bus Type': 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', 'Departing Time': '19:15', 'Duration': '08h 45m', 'Reaching Time': '04:00', 'Star Rating': '4.0', 'Price': '483', 'Seat Availability': '24 Seats available'}
# {'State': 'BIHAR', 'Route Name': 'Hyderabad to Guntur (Andhra Pradesh)', 'Route Link': 'https://www.redbus.in/bus-tickets/hyderabad-to-guntur', 'Bus Name': 'APSRTC - 4249', 'Bus Type': 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', 'Departing Time': '19:45', 'Duration': '08h 35m', 'Reaching Time': '04:20', 'Star Rating': '3.4', 'Price': '483', 'Seat Availability': '20 Seats available'}
# {'State': 'BIHAR', 'Route Name': 'Hyderabad to Guntur (Andhra Pradesh)', 'Route Link': 'https://www.redbus.in/bus-tickets/hyderabad-to-guntur', 'Bus Name': 'APSRTC - 4179', 'Bus Type': 'AMARAVATHI (VOLVO / SCANIA A.C Multi Axle)', 'Departing Time': '20:30', 'Duration': '07h 59m', 'Reaching Time': '04:29', 'Star Rating': '4.5', 'Price': '817', 'Seat Availability': '36 Seats available'}
# {'State': 'BIHAR', 'Route Name': 'Hyderabad to Guntur (Andhra Pradesh)', 'Route Link': 'https://www.redbus.in/bus-tickets/hyderabad-to-guntur', 'Bus Name': 'APSRTC - 42443', 'Bus Type': 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', 'Departing Time': '21:00', 'Duration': '08h 45m', 'Reaching Time': '05:45', 'Star Rating': '3.0', 'Price': '483', 'Seat Availability': '21 Seats available'}
# {'State': 'BIHAR', 'Route Name': 'Hyderabad to Guntur (Andhra Pradesh)', 'Route Link': 'https://www.redbus.in/bus-tickets/hyderabad-to-guntur', 'Bus Name': 'APSRTC - 4629', 'Bus Type': 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', 'Departing Time': '21:00', 'Duration': '08h 00m', 'Reaching Time': '05:00', 'Star Rating': '4.3', 'Price': '483', 'Seat Availability': '32 Seats available'}
# {'State': 'BIHAR', 'Route Name': 'Hyderabad to Guntur (Andhra Pradesh)', 'Route Link': 'https://www.redbus.in/bus-tickets/hyderabad-to-guntur', 'Bus Name': 'APSRTC - 4619', 'Bus Type': 'STAR LINER(NON-AC SLEEPER 2+1)', 'Departing Time': '21:20', 'Duration': '07h 25m', 'Reaching Time': '04:45', 'Star Rating': '4.1', 'Price': '626', 'Seat Availability': '13 Seats available'}
# {'State': 'BIHAR', 'Route Name': 'Hyderabad to Guntur (Andhra Pradesh)', 'Route Link': 'https://www.redbus.in/bus-tickets/hyderabad-to-guntur', 'Bus Name': 'APSRTC - 4199', 'Bus Type': 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', 'Departing Time': '21:40', 'Duration': '08h 25m', 'Reaching Time': '06:05', 'Star Rating': '3.8', 'Price': '483', 'Seat Availability': '34 Seats available'}
# {'State': 'BIHAR', 'Route Name': 'Hyderabad to Guntur (Andhra Pradesh)', 'Route Link': 'https://www.redbus.in/bus-tickets/hyderabad-to-guntur', 'Bus Name': 'APSRTC - 4223', 'Bus Type': 'INDRA(A.C. Seater)', 'Departing Time': '21:45', 'Duration': '07h 10m', 'Reaching Time': '04:55', 'Star Rating': '3.9', 'Price': '585', 'Seat Availability': '15 Seats available'}
# {'State': 'BIHAR', 'Route Name': 'Hyderabad to Guntur (Andhra Pradesh)', 'Route Link': 'https://www.redbus.in/bus-tickets/hyderabad-to-guntur', 'Bus Name': 'APSRTC - 4621', 'Bus Type': 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', 'Departing Time': '21:50', 'Duration': '08h 10m', 'Reaching Time': '06:00', 'Star Rating': '3.8', 'Price': '483', 'Seat Availability': '26 Seats available'}
# {'State': 'BIHAR', 'Route Name': 'Hyderabad to Guntur (Andhra Pradesh)', 'Route Link': 'https://www.redbus.in/bus-tickets/hyderabad-to-guntur', 'Bus Name': 'APSRTC - 4267', 'Bus Type': 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', 'Departing Time': '22:15', 'Duration': '06h 15m', 'Reaching Time': '04:30', 'Star Rating': '3.6', 'Price': '451', 'Seat Availability': '25 Seats available'}
# {'State': 'BIHAR', 'Route Name': 'Hyderabad to Guntur (Andhra Pradesh)', 'Route Link': 'https://www.redbus.in/bus-tickets/hyderabad-to-guntur', 'Bus Name': 'APSRTC - 4181', 'Bus Type': 'STAR LINER(NON-AC SLEEPER 2+1)', 'Departing Time': '22:15', 'Duration': '07h 25m', 'Reaching Time': '05:40', 'Star Rating': '4.0', 'Price': '584', 'Seat Availability': '12 Seats available'}
# {'State': 'BIHAR', 'Route Name': 'Hyderabad to Guntur (Andhra Pradesh)', 'Route Link': 'https://www.redbus.in/bus-tickets/hyderabad-to-guntur', 'Bus Name': 'IntrCity SmartBus', 'Bus Type': 'Scania AC Multi Axle Sleeper (2+1)', 'Departing Time': '23:30', 'Duration': '07h 45m', 'Reaching Time': '07:15', 'Star Rating': '4.5', 'Price': '659', 'Seat Availability': '26 Seats available'}
# {'State': 'BIHAR', 'Route Name': 'Hyderabad to Guntur (Andhra Pradesh)', 'Route Link': 'https://www.redbus.in/bus-tickets/hyderabad-to-guntur', 'Bus Name': 'IntrCity SmartBus', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '23:30', 'Duration': '07h 15m', 'Reaching Time': '06:45', 'Star Rating': '4.5', 'Price': '479', 'Seat Availability': '25 Seats available'}
# {'State': 'BIHAR', 'Route Name': 'Hyderabad to Guntur (Andhra Pradesh)', 'Route Link': 'https://www.redbus.in/bus-tickets/hyderabad-to-guntur', 'Bus Name': 'Zingbus Plus', 'Bus Type': 'A/C Seater / Sleeper (2+1)', 'Departing Time': '23:03', 'Duration': '07h 12m', 'Reaching Time': '06:15', 'Star Rating': '4.5', 'Price': '420', 'Seat Availability': '32 Seats available'}
# {'State': 'BIHAR', 'Route Name': 'Hyderabad to Guntur (Andhra Pradesh)', 'Route Link': 'https://www.redbus.in/bus-tickets/hyderabad-to-guntur', 'Bus Name': 'IntrCity SmartBus', 'Bus Type': 'Scania AC Multi Axle Sleeper (2+1)', 'Departing Time': '23:10', 'Duration': '07h 40m', 'Reaching Time': '06:50', 'Star Rating': '4.5', 'Price': '629', 'Seat Availability': '26 Seats available'}
# {'State': 'BIHAR', 'Route Name': 'Hyderabad to Guntur (Andhra Pradesh)', 'Route Link': 'https://www.redbus.in/bus-tickets/hyderabad-to-guntur', 'Bus Name': 'IntrCity SmartBus', 'Bus Type': 'AC Sleeper (2+1)', 'Departing Time': '23:40', 'Duration': '07h 00m', 'Reaching Time': '06:40', 'Star Rating': '4.4', 'Price': '599', 'Seat Availability': '20 Seats available'}
# Error clicking 'View Buses' button for Hyderabad to Kurnool: Message:
#
# {'State': 'BIHAR', 'Route Name': 'Hyderabad to Kurnool', 'Route Link': 'https://www.redbus.in/bus-tickets/hyderabad-to-kurnool', 'Bus Name': 'APSRTC - 6436', 'Bus Type': 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', 'Departing Time': '10:30', 'Duration': '04h 30m', 'Reaching Time': '15:00', 'Star Rating': '3.5', 'Price': '344', 'Seat Availability': '32 Seats available'}
# {'State': 'BIHAR', 'Route Name': 'Hyderabad to Kurnool', 'Route Link': 'https://www.redbus.in/bus-tickets/hyderabad-to-kurnool', 'Bus Name': 'APSRTC - 6606', 'Bus Type': 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', 'Departing Time': '11:00', 'Duration': '04h 30m', 'Reaching Time': '15:30', 'Star Rating': '3.8', 'Price': '344', 'Seat Availability': '32 Seats available'}
# {'State': 'BIHAR', 'Route Name': 'Hyderabad to Kurnool', 'Route Link': 'https://www.redbus.in/bus-tickets/hyderabad-to-kurnool', 'Bus Name': 'APSRTC - 6260', 'Bus Type': 'INDRA(A.C. Seater)', 'Departing Time': '11:15', 'Duration': '04h 00m', 'Reaching Time': '15:15', 'Star Rating': '3.1', 'Price': '416', 'Seat Availability': '36 Seats available'}
# {'State': 'BIHAR', 'Route Name': 'Hyderabad to Kurnool', 'Route Link': 'https://www.redbus.in/bus-tickets/hyderabad-to-kurnool', 'Bus Name': '', 'Bus Type': '', 'Departing Time': '', 'Duration': '', 'Reaching Time': '', 'Star Rating': '', 'Price': '', 'Seat Availability': ''}
# Error clicking 'View Buses' button for Vinukonda to Hyderabad: Message:
#
# {'State': 'BIHAR', 'Route Name': 'Vinukonda to Hyderabad', 'Route Link': 'https://www.redbus.in/bus-tickets/vinukonda-to-hyderabad', 'Bus Name': 'APSRTC - 45860', 'Bus Type': 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', 'Departing Time': '10:30', 'Duration': '06h 09m', 'Reaching Time': '16:39', 'Star Rating': '4.0', 'Price': '467', 'Seat Availability': '12 Seats available'}
# {'State': 'BIHAR', 'Route Name': 'Vinukonda to Hyderabad', 'Route Link': 'https://www.redbus.in/bus-tickets/vinukonda-to-hyderabad', 'Bus Name': 'APSRTC - 5984', 'Bus Type': 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', 'Departing Time': '21:15', 'Duration': '05h 30m', 'Reaching Time': '02:45', 'Star Rating': '3.9', 'Price': '467', 'Seat Availability': '33 Seats available'}
# {'State': 'BIHAR', 'Route Name': 'Vinukonda to Hyderabad', 'Route Link': 'https://www.redbus.in/bus-tickets/vinukonda-to-hyderabad', 'Bus Name': 'APSRTC - 4590', 'Bus Type': 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', 'Departing Time': '21:30', 'Duration': '05h 15m', 'Reaching Time': '02:45', 'Star Rating': '3.5', 'Price': '467', 'Seat Availability': '34 Seats available'}
# {'State': 'BIHAR', 'Route Name': 'Vinukonda to Hyderabad', 'Route Link': 'https://www.redbus.in/bus-tickets/vinukonda-to-hyderabad', 'Bus Name': '', 'Bus Type': '', 'Departing Time': '', 'Duration': '', 'Reaching Time': '', 'Star Rating': '', 'Price': '', 'Seat Availability': ''}
# Error clicking 'View Buses' button for Hyderabad to Addanki: Message:
#
# {'State': 'BIHAR', 'Route Name': 'Hyderabad to Addanki', 'Route Link': 'https://www.redbus.in/bus-tickets/hyderabad-to-addanki', 'Bus Name': 'APSRTC - 5870', 'Bus Type': 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', 'Departing Time': '18:30', 'Duration': '08h 30m', 'Reaching Time': '03:00', 'Star Rating': '4.0', 'Price': '462', 'Seat Availability': '21 Seats available'}
# {'State': 'BIHAR', 'Route Name': 'Hyderabad to Addanki', 'Route Link': 'https://www.redbus.in/bus-tickets/hyderabad-to-addanki', 'Bus Name': 'APSRTC - 5859', 'Bus Type': 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', 'Departing Time': '19:00', 'Duration': '08h 00m', 'Reaching Time': '03:00', 'Star Rating': '4.0', 'Price': '495', 'Seat Availability': '34 Seats available'}
# {'State': 'BIHAR', 'Route Name': 'Hyderabad to Addanki', 'Route Link': 'https://www.redbus.in/bus-tickets/hyderabad-to-addanki', 'Bus Name': 'APSRTC - 5994', 'Bus Type': 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', 'Departing Time': '19:30', 'Duration': '09h 00m', 'Reaching Time': '04:30', 'Star Rating': '3.1', 'Price': '495', 'Seat Availability': '25 Seats available'}
# {'State': 'BIHAR', 'Route Name': 'Hyderabad to Addanki', 'Route Link': 'https://www.redbus.in/bus-tickets/hyderabad-to-addanki', 'Bus Name': 'APSRTC - 5922', 'Bus Type': 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', 'Departing Time': '19:45', 'Duration': '08h 30m', 'Reaching Time': '04:15', 'Star Rating': '4.3', 'Price': '495', 'Seat Availability': '24 Seats available'}
# {'State': 'BIHAR', 'Route Name': 'Hyderabad to Addanki', 'Route Link': 'https://www.redbus.in/bus-tickets/hyderabad-to-addanki', 'Bus Name': '', 'Bus Type': '', 'Departing Time': '', 'Duration': '', 'Reaching Time': '', 'Star Rating': '', 'Price': '', 'Seat Availability': ''}
# Collected Bus Details: [{'State': 'BIHAR', 'Route Name': 'Hyderabad to Guntur (Andhra Pradesh)', 'Route Link': 'https://www.redbus.in/bus-tickets/hyderabad-to-guntur', 'Bus Name': 'APSRTC - 4197', 'Bus Type': 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', 'Departing Time': '10:30', 'Duration': '08h 20m', 'Reaching Time': '18:50', 'Star Rating': '3.5', 'Price': '451', 'Seat Availability': '26 Seats available'}, {'State': 'BIHAR', 'Route Name': 'Hyderabad to Guntur (Andhra Pradesh)', 'Route Link': 'https://www.redbus.in/bus-tickets/hyderabad-to-guntur', 'Bus Name': 'APSRTC - 4612', 'Bus Type': 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', 'Departing Time': '19:15', 'Duration': '08h 45m', 'Reaching Time': '04:00', 'Star Rating': '4.0', 'Price': '483', 'Seat Availability': '24 Seats available'}, {'State': 'BIHAR', 'Route Name': 'Hyderabad to Guntur (Andhra Pradesh)', 'Route Link': 'https://www.redbus.in/bus-tickets/hyderabad-to-guntur', 'Bus Name': 'APSRTC - 4249', 'Bus Type': 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', 'Departing Time': '19:45', 'Duration': '08h 35m', 'Reaching Time': '04:20', 'Star Rating': '3.4', 'Price': '483', 'Seat Availability': '20 Seats available'}, {'State': 'BIHAR', 'Route Name': 'Hyderabad to Guntur (Andhra Pradesh)', 'Route Link': 'https://www.redbus.in/bus-tickets/hyderabad-to-guntur', 'Bus Name': 'APSRTC - 4179', 'Bus Type': 'AMARAVATHI (VOLVO / SCANIA A.C Multi Axle)', 'Departing Time': '20:30', 'Duration': '07h 59m', 'Reaching Time': '04:29', 'Star Rating': '4.5', 'Price': '817', 'Seat Availability': '36 Seats available'}, {'State': 'BIHAR', 'Route Name': 'Hyderabad to Guntur (Andhra Pradesh)', 'Route Link': 'https://www.redbus.in/bus-tickets/hyderabad-to-guntur', 'Bus Name': 'APSRTC - 42443', 'Bus Type': 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', 'Departing Time': '21:00', 'Duration': '08h 45m', 'Reaching Time': '05:45', 'Star Rating': '3.0', 'Price': '483', 'Seat Availability': '21 Seats available'}, {'State': 'BIHAR', 'Route Name': 'Hyderabad to Guntur (Andhra Pradesh)', 'Route Link': 'https://www.redbus.in/bus-tickets/hyderabad-to-guntur', 'Bus Name': 'APSRTC - 4629', 'Bus Type': 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', 'Departing Time': '21:00', 'Duration': '08h 00m', 'Reaching Time': '05:00', 'Star Rating': '4.3', 'Price': '483', 'Seat Availability': '32 Seats available'}, {'State': 'BIHAR', 'Route Name': 'Hyderabad to Guntur (Andhra Pradesh)', 'Route Link': 'https://www.redbus.in/bus-tickets/hyderabad-to-guntur', 'Bus Name': 'APSRTC - 4619', 'Bus Type': 'STAR LINER(NON-AC SLEEPER 2+1)', 'Departing Time': '21:20', 'Duration': '07h 25m', 'Reaching Time': '04:45', 'Star Rating': '4.1', 'Price': '626', 'Seat Availability': '13 Seats available'}, {'State': 'BIHAR', 'Route Name': 'Hyderabad to Guntur (Andhra Pradesh)', 'Route Link': 'https://www.redbus.in/bus-tickets/hyderabad-to-guntur', 'Bus Name': 'APSRTC - 4199', 'Bus Type': 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', 'Departing Time': '21:40', 'Duration': '08h 25m', 'Reaching Time': '06:05', 'Star Rating': '3.8', 'Price': '483', 'Seat Availability': '34 Seats available'}, {'State': 'BIHAR', 'Route Name': 'Hyderabad to Guntur (Andhra Pradesh)', 'Route Link': 'https://www.redbus.in/bus-tickets/hyderabad-to-guntur', 'Bus Name': 'APSRTC - 4223', 'Bus Type': 'INDRA(A.C. Seater)', 'Departing Time': '21:45', 'Duration': '07h 10m', 'Reaching Time': '04:55', 'Star Rating': '3.9', 'Price': '585', 'Seat Availability': '15 Seats available'}, {'State': 'BIHAR', 'Route Name': 'Hyderabad to Guntur (Andhra Pradesh)', 'Route Link': 'https://www.redbus.in/bus-tickets/hyderabad-to-guntur', 'Bus Name': 'APSRTC - 4621', 'Bus Type': 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', 'Departing Time': '21:50', 'Duration': '08h 10m', 'Reaching Time': '06:00', 'Star Rating': '3.8', 'Price': '483', 'Seat Availability': '26 Seats available'}, {'State': 'BIHAR', 'Route Name': 'Hyderabad to Guntur (Andhra Pradesh)', 'Route Link': 'https://www.redbus.in/bus-tickets/hyderabad-to-guntur', 'Bus  ...
