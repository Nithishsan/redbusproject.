# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
import time
import mysql.connector

# Connect Database
db_connection = mysql.connector.connect(
    host="localhost",
    user="root",
    password="1234",
    database="redbus"
)
cursor = db_connection.cursor()
print("Database connected Successfully")

# SQL to create table
create_table_query = """
CREATE TABLE IF NOT EXISTS BusDetails(
    id INT PRIMARY KEY AUTO_INCREMENT,
    state VARCHAR(100) DEFAULT 'Andhra Pradesh',
    route_name VARCHAR(255),
    route_link VARCHAR(255),
    bus_name VARCHAR(255),
    bus_type VARCHAR(255),
    departing_time TEXT,
    duration VARCHAR(50),
    reaching_time TEXT,
    star_rating TEXT,
    price VARCHAR(50),
    seat_availability TEXT
);
"""
cursor.execute(create_table_query)
print("Table created successfully")

# Initialize WebDriver and WebDriverWait
driver = webdriver.Chrome()
wait = WebDriverWait(driver, 10)

# Open the webpage
driver.get("")
driver.maximize_window()
time.sleep(2)

# Function to scrape route data
def scrape_page():
    routescontainer = wait.until(EC.presence_of_all_elements_located((By.XPATH, '')))
    route_data = []  # List to store the scraped route data
    for route in routescontainer:
        route_data.append({
            'Route Name': route.text,
            'Route Link': route.get_attribute('href')
        })
    return route_data  # Return the scraped data

# Function to navigate pages
def navigate_pages():
    all_routes = []
    for page_number in range(1, 6):  # Limit to 5 pages
        try:
            routes = scrape_page()
            all_routes.extend(routes)
            pagination_container = wait.until(EC.presence_of_element_located((By.XPATH, '//*[@id="root"]/div/div[4]/div[12]')))
            next_page_button = pagination_container.find_element(By.XPATH, f'.//div[contains(@class,"DC_117_pageTabs") and text()="{page_number + 1}"]')
            next_page_button.click()
            wait.until(EC.text_to_be_present_in_element(
                (By.XPATH, '//div[contains(@class, "DC_117_pageTabs DC_117_pageActive")]'), str(page_number + 1))
            )
            time.sleep(2)  # Allow page to load
        except Exception as e:
            print(f"Pagination error at page {page_number + 1}: {e}")
            break
    return all_routes

# Function to scrape bus details
def collect_bus_details(route_data):
    alldetails = []
    for data in route_data:
        link = data['Route Link']
        route_name = data['Route Name']
        try:
            driver.get(link)
            time.sleep(2)
            try:
                view_buses_buttons = wait.until(EC.presence_of_all_elements_located((By.XPATH, "//div[@class='button']")))
                for button in view_buses_buttons:
                    wait.until(EC.element_to_be_clickable(button)).click()
                    time.sleep(3)  # Wait for the buses to load
            except Exception as e:
                print(f"Error clicking 'View Buses' button for {route_name}: {e}")

            bus_containers = wait.until(EC.presence_of_all_elements_located((By.XPATH, "//div[contains(@class, 'clearfix row-one')]")))
            for bus_container in bus_containers:
                try:
                    busname = bus_container.find_element(By.XPATH, ".//div[@class='travels lh-24 f-bold d-color']").text
                    bustype = bus_container.find_element(By.XPATH, ".//div[@class='bus-type f-12 m-top-16 l-color evBus']").text
                    departuretiming = bus_container.find_element(By.XPATH, ".//div[@class='dp-time f-19 d-color f-bold']").text
                    duration = bus_container.find_element(By.XPATH, ".//div[@class='dur l-color lh-24']").text
                    reachtiming = bus_container.find_element(By.XPATH, ".//div[@class='bp-time f-19 d-color disp-Inline']").text
                    rating = bus_container.find_element(By.XPATH, ".//div[@class='rating-sec lh-24']").text
                    price = bus_container.find_element(By.XPATH, ".//span[contains(@class,'f-19 f-bold') or contains(@class,'f-bold f-19')]").text
                    seat = bus_container.find_element(By.XPATH, ".//div[contains(@class, 'seat-left m-top-30') or contains(@class,'seat-left m-top-16')]").text

                    details = {
                        'State': "WESTBENGAL",
                        'Route Name': route_name,
                        'Route Link': link,
                        'Bus Name': busname,
                        'Bus Type': bustype,
                        'Departing Time': departuretiming,
                        'Duration': duration,
                        'Reaching Time': reachtiming,
                        'Star Rating': rating,
                        'Price': price,
                        'Seat Availability': seat,
                    }
                     # Check if the details already exist in the list
                    if details not in alldetails:
                        print(details)
                        alldetails.append(details)

                        # Insert data into the database
                        insert_query = """
                        INSERT IGNORE INTO BusDetails (state, route_name, route_link, bus_name, bus_type, departing_time, duration, reaching_time, star_rating, price, seat_availability)
                        VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
                        """
                        cursor.execute(insert_query, (
                            details['State'],
                            details['Route Name'],
                            details['Route Link'],
                            details['Bus Name'],
                            details['Bus Type'],
                            details['Departing Time'],
                            details['Duration'],
                            details['Reaching Time'],
                            details['Star Rating'],
                            details['Price'],
                            details['Seat Availability']
                        ))
                        db_connection.commit()
                except Exception as e:
                    print(f"Error scraping bus details for {route_name}: {e}")
        except Exception as e:
            print(f"Error accessing route link {link}: {e}")
    return alldetails

# Main execution
routes = navigate_pages()
print("Scraped Routes:", routes)
bus_details = collect_bus_details(routes)
print("Collected Bus Details:", bus_details)
# Out:
# Pagination error at page 2: Message: element click intercepted: Element is not clickable at point (739, 2096)
#   (Session info: chrome=131.0.6778.265)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7E47F80D5+2992373]
# 	(No symbol) [0x00007FF7E448BFD0]
# 	(No symbol) [0x00007FF7E432590A]
# 	(No symbol) [0x00007FF7E4380F2E]
# 	(No symbol) [0x00007FF7E437E9CC]
# 	(No symbol) [0x00007FF7E437BBA6]
# 	(No symbol) [0x00007FF7E437AB01]
# 	(No symbol) [0x00007FF7E436CD40]
# 	(No symbol) [0x00007FF7E439F36A]
# 	(No symbol) [0x00007FF7E436C596]
# 	(No symbol) [0x00007FF7E439F580]
# 	(No symbol) [0x00007FF7E43BF584]
# 	(No symbol) [0x00007FF7E439F113]
# 	(No symbol) [0x00007FF7E436A918]
# 	(No symbol) [0x00007FF7E436BA81]
# 	GetHandleVerifier [0x00007FF7E4856A2D+3379789]
# 	GetHandleVerifier [0x00007FF7E486C32D+3468109]
# 	GetHandleVerifier [0x00007FF7E4860043+3418211]
# 	GetHandleVerifier [0x00007FF7E45EC78B+847787]
# 	(No symbol) [0x00007FF7E449757F]
# 	(No symbol) [0x00007FF7E4492FC4]
# 	(No symbol) [0x00007FF7E449315D]
# 	(No symbol) [0x00007FF7E4482979]
# 	BaseThreadInitThunk [0x00007FFC439DE8D7+23]
# 	RtlUserThreadStart [0x00007FFC4589FBCC+44]
#
# Scraped Routes: [{'Route Name': 'Kolkata to Digha', 'Route Link': 'https://www.redbus.in/bus-tickets/kolkata-to-digha'}]
# Error clicking 'View Buses' button for Kolkata to Digha: Message:
#
# Collected Bus Details: [{'State': 'WESTBENGAL', 'Route Name': 'Kolkata to Digha', 'Route Link': 'https://www.redbus.in/bus-tickets/kolkata-to-digha', 'Bus Name': 'Shyamoli Paribahan Pvt Ltd', 'Bus Type': 'VE A/C Seater (2+2)', 'Departing Time': '23:30', 'Duration': '05h 00m', 'Reaching Time': '04:30', 'Star Rating': '4.4', 'Price': '300', 'Seat Availability': '33 Seats available'}, {'State': 'WESTBENGAL', 'Route Name': 'Kolkata to Digha', 'Route Link': 'https://www.redbus.in/bus-tickets/kolkata-to-digha', 'Bus Name': 'Express Line', 'Bus Type': 'VE A/C Seater (2+2)', 'Departing Time': '23:45', 'Duration': '05h 00m', 'Reaching Time': '04:45', 'Star Rating': '4.4', 'Price': '299', 'Seat Availability': '32 Seats available'}, {'State': 'WESTBENGAL', 'Route Name': 'Kolkata to Digha', 'Route Link': 'https://www.redbus.in/bus-tickets/kolkata-to-digha', 'Bus Name': 'Sagufta Travels(Maa chandi)', 'Bus Type': 'A/C Seater / Sleeper (2+2)', 'Departing Time': '23:57', 'Duration': '05h 13m', 'Reaching Time': '05:10', 'Star Rating': '4.3', 'Price': '315', 'Seat Availability': '29 Seats available'}, {'State': 'WESTBENGAL', 'Route Name': 'Kolkata to Digha', 'Route Link': 'https://www.redbus.in/bus-tickets/kolkata-to-digha', 'Bus Name': 'Maa Chandi Travels', 'Bus Type': 'A/C Seater / Sleeper (2+2)', 'Departing Time': '23:57', 'Duration': '05h 13m', 'Reaching Time': '05:10', 'Star Rating': '4.3', 'Price': '360', 'Seat Availability': '15 Seats available'}, {'State': 'WESTBENGAL', 'Route Name': 'Kolkata to Digha', 'Route Link': 'https://www.redbus.in/bus-tickets/kolkata-to-digha', 'Bus Name': '', 'Bus Type': '', 'Departing Time': '', 'Duration': '', 'Reaching Time': '', 'Star Rating': '', 'Price': '', 'Seat Availability': ''}]

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver import ActionChains
import time
import mysql.connector
import pandas as pd
# Connect Database
db_connection = mysql.connector.connect(
    host="localhost",
    user="root",
    password="1234",
    database="redbus"
)
cursor = db_connection.cursor()
print("Database connected Successfully")

# SQL to create table
create_table_query = """
CREATE TABLE IF NOT EXISTS BusDetails(
    id INT PRIMARY KEY AUTO_INCREMENT,
    state VARCHAR(100) DEFAULT 'Andhra Pradesh',
    route_name VARCHAR(255),
    route_link VARCHAR(255),
    bus_name VARCHAR(255),
    bus_type VARCHAR(255),
    departing_time TEXT,
    duration VARCHAR(50),
    reaching_time TEXT,
    star_rating TEXT,
    price VARCHAR(50),
    seat_availability TEXT
);
"""
cursor.execute(create_table_query)
print("Table created successfully")

# Initialize the WebDriver
driver = webdriver.Chrome()
driver.implicitly_wait(5)
wait = WebDriverWait(driver, 10)

# Navigate to the upsrtc Bus Routes page
driver.get("https://www.redbus.in/online-booking/south-bengal-state-transport-corporation-sbstc/?utm_source=rtchometile")
driver.maximize_window()
time.sleep(2)
route_data = []
# Function to scrape route data
def scrape_page():
    routescontainer = wait.until(EC.presence_of_all_elements_located((By.XPATH, '//*[@id="root"]/div/div[4]/div[2]/div[1]/a')))
      
    for route in routescontainer:
        route_data.append({
            'Route Name': route.text,
            'Route Link': route.get_attribute('href')
        })
    return route_data  # Return the scraped data

# Pagination to collect routes from multiple pages
for page_number in range(1, 6):
    try:
        pagination_container = wait.until(EC.presence_of_element_located((By.XPATH, '//*[@id="root"]/div/div[4]/div[12]')))
        next_page_button = pagination_container.find_element(By.XPATH, f'.//div[contains(@class,"DC_117_pageTabs") and text()="{page_number + 1}"]')

        actions = ActionChains(driver)
        actions.move_to_element(next_page_button).perform()
        next_page_button.click()
        time.sleep(1)

        wait.until(EC.text_to_be_present_in_element((By.XPATH, f'.//div[contains(@class,"DC_117_pageTabs DC_117_pageActive")]'), str(page_number + 1)))
        time.sleep(2)

        scrape_page()

    except Exception as e:
        print(e)
        break


# Function to scrape bus details
def collect_bus_details():
    alldetails = []
    for data in route_data:
        link = data['Route Link']
        route_name = data['Route Name']
        try:
            driver.get(link)
            time.sleep(2)
            try:
                view_buses_buttons = wait.until(EC.presence_of_all_elements_located((By.XPATH, "//div[@class='button']")))
                for button in view_buses_buttons:
                    wait.until(EC.element_to_be_clickable(button)).click()
                    time.sleep(3)  # Wait for the buses to load
            except Exception as e:
                print(f"Error clicking 'View Buses' button for {route_name}: {e}")

            bus_containers = wait.until(EC.presence_of_all_elements_located((By.XPATH, "//div[contains(@class, 'clearfix bus-item')]")))
            for bus_container in bus_containers:
                try:
                    busname = bus_container.find_element(By.XPATH, ".//div[@class='travels lh-24 f-bold d-color']").text
                    bustype = bus_container.find_element(By.XPATH, ".//div[@class='bus-type f-12 m-top-16 l-color evBus']").text
                    departuretiming = bus_container.find_element(By.XPATH, ".//div[@class='dp-time f-19 d-color f-bold']").text
                    duration = bus_container.find_element(By.XPATH, ".//div[@class='dur l-color lh-24']").text
                    reachtiming = bus_container.find_element(By.XPATH, ".//div[@class='bp-time f-19 d-color disp-Inline']").text
                    rating = bus_container.find_element(By.XPATH, ".//div[@class='rating-sec lh-24']").text
                    price = bus_container.find_element(By.XPATH, ".//span[contains(@class,'f-19 f-bold') or contains(@class,'f-bold f-19')]").text
                    seat = bus_container.find_element(By.XPATH, ".//div[contains(@class, 'seat-left m-top-30') or contains(@class,'seat-left m-top-16')]").text

                    details = {
                        'State': "Southbengal",
                        'Route Name': route_name,
                        'Route Link': link,
                        'Bus Name': busname,
                        'Bus Type': bustype,
                        'Departing Time': departuretiming,
                        'Duration': duration,
                        'Reaching Time': reachtiming,
                        'Star Rating': rating,
                        'Price': price,
                        'Seat Availability': seat,
                    }
                    # Check if the details already exist in the list
                    if details not in alldetails:
                        print(details)
                        alldetails.append(details)

                        # Insert data into the database
                        insert_query = """
                        INSERT IGNORE INTO BusDetails (state, route_name, route_link, bus_name, bus_type, departing_time, duration, reaching_time, star_rating, price, seat_availability)
                        VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
                        """
                        cursor.execute(insert_query, (
                            details['State'],
                            details['Route Name'],
                            details['Route Link'],
                            details['Bus Name'],
                            details['Bus Type'],
                            details['Departing Time'],
                            details['Duration'],
                            details['Reaching Time'],
                            details['Star Rating'],
                            details['Price'],
                            details['Seat Availability']
                        ))
                        db_connection.commit()
                except Exception as e:
                    print(f"Error scraping bus details for {route_name}: {e}")
        except Exception as e:
            print(f"Error accessing route link {link}: {e}")
    return alldetails

# Main execution


bus_details = collect_bus_details()
print("Collected Bus Details:", bus_details)


df = pd.DataFrame(bus_details)
df.to_csv("Southbengal.csv", index=False)

# Close the WebDriver
driver.quit()

# Close the Database Connection
cursor.close()
db_connection.close()
# Out:
# Database connected Successfully
# Table created successfully
# Message:
# Stacktrace:
# 	GetHandleVerifier [0x00007FF6859502F5+28725]
# 	(No symbol) [0x00007FF6858B2AE0]
# 	(No symbol) [0x00007FF68574510A]
# 	(No symbol) [0x00007FF6857993D2]
# 	(No symbol) [0x00007FF6857995FC]
# 	(No symbol) [0x00007FF6857E3407]
# 	(No symbol) [0x00007FF6857BFFEF]
# 	(No symbol) [0x00007FF6857E0181]
# 	(No symbol) [0x00007FF6857BFD53]
# 	(No symbol) [0x00007FF68578A0E3]
# 	(No symbol) [0x00007FF68578B471]
# 	GetHandleVerifier [0x00007FF685C7F30D+3366989]
# 	GetHandleVerifier [0x00007FF685C912F0+3440688]
# 	GetHandleVerifier [0x00007FF685C878FD+3401277]
# 	GetHandleVerifier [0x00007FF685A1AAAB+858091]
# 	(No symbol) [0x00007FF6858BE74F]
# 	(No symbol) [0x00007FF6858BA304]
# 	(No symbol) [0x00007FF6858BA49D]
# 	(No symbol) [0x00007FF6858A8B69]
# 	BaseThreadInitThunk [0x00007FFFFD2CE8D7+23]
# 	RtlUserThreadStart [0x00007FFFFE93FBCC+44]
#
# {'State': 'Southbengal', 'Route Name': 'Kolkata to Asansol (West Bengal)', 'Route Link': 'https://www.redbus.in/bus-tickets/kolkata-to-asansol', 'Bus Name': 'SBSTC-KOLKATA - ASANSOL - 10:30 (HOWRAH DEPOT) - 763', 'Bus Type': 'Non AC Seater (2+3)', 'Departing Time': '10:30', 'Duration': '04h 30m', 'Reaching Time': '15:00', 'Star Rating': '2.5', 'Price': '180', 'Seat Availability': '51 Seats available'}
# {'State': 'Southbengal', 'Route Name': 'Kolkata to Asansol (West Bengal)', 'Route Link': 'https://www.redbus.in/bus-tickets/kolkata-to-asansol', 'Bus Name': 'SBSTC-KOLKATA - ASANSOL - 10:45 (ASN DEPOT) - 449', 'Bus Type': 'Non AC Seater (2+3)', 'Departing Time': '10:45', 'Duration': '04h 15m', 'Reaching Time': '15:00', 'Star Rating': '3.3', 'Price': '180', 'Seat Availability': '52 Seats available'}
# {'State': 'Southbengal', 'Route Name': 'Kolkata to Asansol (West Bengal)', 'Route Link': 'https://www.redbus.in/bus-tickets/kolkata-to-asansol', 'Bus Name': 'SBSTC-KOLKATA - PURULIA - VIA - ASN - 11:00 (HWH DEPOT) - 2681', 'Bus Type': 'Non AC Seater (2+3)', 'Departing Time': '11:00', 'Duration': '04h 30m', 'Reaching Time': '15:30', 'Star Rating': '3.5', 'Price': '180', 'Seat Availability': '49 Seats available'}
# {'State': 'Southbengal', 'Route Name': 'Kolkata to Asansol (West Bengal)', 'Route Link': 'https://www.redbus.in/bus-tickets/kolkata-to-asansol', 'Bus Name': 'SBSTC-KOLKATA - ASANSOL - 11:40 (ASANSOL DEPOT) - 250', 'Bus Type': 'Non AC Seater (2+3)', 'Departing Time': '11:40', 'Duration': '04h 30m', 'Reaching Time': '16:10', 'Star Rating': '3.8', 'Price': '180', 'Seat Availability': '52 Seats available'}
# {'State': 'Southbengal', 'Route Name': 'Kolkata to Asansol (West Bengal)', 'Route Link': 'https://www.redbus.in/bus-tickets/kolkata-to-asansol', 'Bus Name': 'SBSTC-KOLKATA - ASANSOL - L/S - 12:30 (ASANSOL DEPOT) - 252', 'Bus Type': 'Non AC Seater (2+3)', 'Departing Time': '12:30', 'Duration': '04h 30m', 'Reaching Time': '17:00', 'Star Rating': '3.0', 'Price': '180', 'Seat Availability': '51 Seats available'}
# {'State': 'Southbengal', 'Route Name': 'Kolkata to Asansol (West Bengal)', 'Route Link': 'https://www.redbus.in/bus-tickets/kolkata-to-asansol', 'Bus Name': 'WBTC (CTC) KOLKATA - ASANSOL - PURULIA (AC VOLVO) Banglashree Express - 133|13:45', 'Bus Type': 'Volvo AC Seater (2+2)', 'Departing Time': '13:45', 'Duration': '03h 55m', 'Reaching Time': '17:40', 'Star Rating': '3.3', 'Price': '430', 'Seat Availability': '25 Seats available'}
# {'State': 'Southbengal', 'Route Name': 'Kolkata to Asansol (West Bengal)', 'Route Link': 'https://www.redbus.in/bus-tickets/kolkata-to-asansol', 'Bus Name': 'SHYAMOLI Pvt. Ltd.(Karunamoyee)', 'Bus Type': 'Scania Multi-Axle AC Semi Sleeper (2+2)', 'Departing Time': '10:00', 'Duration': '05h 00m', 'Reaching Time': '15:00', 'Star Rating': '4.3', 'Price': '529', 'Seat Availability': '9 Seats available'}
# {'State': 'Southbengal', 'Route Name': 'Kolkata to Asansol (West Bengal)', 'Route Link': 'https://www.redbus.in/bus-tickets/kolkata-to-asansol', 'Bus Name': 'SHYAMOLI Pvt. Ltd.(Karunamoyee)', 'Bus Type': 'Scania Multi-Axle AC Semi Sleeper (2+2)', 'Departing Time': '10:00', 'Duration': '05h 00m', 'Reaching Time': '15:00', 'Star Rating': '3.8', 'Price': '524', 'Seat Availability': '7 Seats available'}
# {'State': 'Southbengal', 'Route Name': 'Kolkata to Asansol (West Bengal)', 'Route Link': 'https://www.redbus.in/bus-tickets/kolkata-to-asansol', 'Bus Name': 'Shyamoli Paribahan Pvt Ltd', 'Bus Type': 'Volvo A/C Seater (2+2)', 'Departing Time': '10:05', 'Duration': '04h 10m', 'Reaching Time': '14:15', 'Star Rating': '4.1', 'Price': '524', 'Seat Availability': '15 Seats available'}
# {'State': 'Southbengal', 'Route Name': 'Kolkata to Asansol (West Bengal)', 'Route Link': 'https://www.redbus.in/bus-tickets/kolkata-to-asansol', 'Bus Name': 'Express Line', 'Bus Type': 'Volvo 9600 A/C Seater (2+2)', 'Departing Time': '10:25', 'Duration': '05h 00m', 'Reaching Time': '15:25', 'Star Rating': '4.4', 'Price': '524', 'Seat Availability': '43 Seats available'}
# {'State': 'Southbengal', 'Route Name': 'Siliguri to Kolkata', 'Route Link': 'https://www.redbus.in/bus-tickets/siliguri-to-kolkata', 'Bus Name': 'NBSTC-COB-KOL-R1-13:30 - 156428', 'Bus Type': 'Non AC Seater 2+2', 'Departing Time': '17:15', 'Duration': '13h 15m', 'Reaching Time': '06:30', 'Star Rating': '3.7', 'Price': '486', 'Seat Availability': '11 Seats available'}
# {'State': 'Southbengal', 'Route Name': 'Siliguri to Kolkata', 'Route Link': 'https://www.redbus.in/bus-tickets/siliguri-to-kolkata', 'Bus Name': 'NBSTC-SLG-RAI-KOL 06:00PM - 179288', 'Bus Type': 'Non AC Seater (2+2)', 'Departing Time': '18:00', 'Duration': '12h 00m', 'Reaching Time': '06:00', 'Star Rating': '3.6', 'Price': '486', 'Seat Availability': '13 Seats available'}
# {'State': 'Southbengal', 'Route Name': 'Siliguri to Kolkata', 'Route Link': 'https://www.redbus.in/bus-tickets/siliguri-to-kolkata', 'Bus Name': 'NBSTC-SLG-KOL-R1-18:30 - 156410', 'Bus Type': 'NON A/C Seater Push Back (2+2)', 'Departing Time': '18:30', 'Duration': '12h 00m', 'Reaching Time': '06:30', 'Star Rating': '4.3', 'Price': '486', 'Seat Availability': '3 Seats available'}
# {'State': 'Southbengal', 'Route Name': 'Siliguri to Kolkata', 'Route Link': 'https://www.redbus.in/bus-tickets/siliguri-to-kolkata', 'Bus Name': 'SBSTC-SILIGURI - KOLKATA - VOLVO - 19:35 SPL FARE - 4021', 'Bus Type': 'Volvo Multi-Axle A/C Seater (2+2)', 'Departing Time': '19:35', 'Duration': '10h 25m', 'Reaching Time': '06:00', 'Star Rating': '4.2', 'Price': '910', 'Seat Availability': '46 Seats available'}
# {'State': 'Southbengal', 'Route Name': 'Siliguri to Kolkata', 'Route Link': 'https://www.redbus.in/bus-tickets/siliguri-to-kolkata', 'Bus Name': 'Raipur Cruiser', 'Bus Type': 'Volvo 9600 Multi-Axle A/C Sleeper (2+1)', 'Departing Time': '18:00', 'Duration': '13h 30m', 'Reaching Time': '07:30', 'Star Rating': '4.8', 'Price': '1500', 'Seat Availability': '21 Seats available'}
# {'State': 'Southbengal', 'Route Name': 'Siliguri to Kolkata', 'Route Link': 'https://www.redbus.in/bus-tickets/siliguri-to-kolkata', 'Bus Name': 'Modern Travels', 'Bus Type': 'Bharat Benz A/C Sleeper (2+1)', 'Departing Time': '19:30', 'Duration': '12h 15m', 'Reaching Time': '07:45', 'Star Rating': '4.7', 'Price': '1430', 'Seat Availability': '21 Seats available'}
# {'State': 'Southbengal', 'Route Name': 'Siliguri to Kolkata', 'Route Link': 'https://www.redbus.in/bus-tickets/siliguri-to-kolkata', 'Bus Name': 'Poulami Paribahan', 'Bus Type': 'Volvo Multi-Axle A/C seater/sleeper (2+1)', 'Departing Time': '18:00', 'Duration': '12h 15m', 'Reaching Time': '06:15', 'Star Rating': '4.1', 'Price': '1200', 'Seat Availability': '30 Seats available'}
# {'State': 'Southbengal', 'Route Name': 'Siliguri to Kolkata', 'Route Link': 'https://www.redbus.in/bus-tickets/siliguri-to-kolkata', 'Bus Name': 'Lokenath Bus Service', 'Bus Type': 'Volvo Multi-Axle A/C Seater/Sleeper (2+1)', 'Departing Time': '18:45', 'Duration': '12h 00m', 'Reaching Time': '06:45', 'Star Rating': '4.4', 'Price': '1199', 'Seat Availability': '39 Seats available'}
# {'State': 'Southbengal', 'Route Name': 'Digha to Barasat (West Bengal)', 'Route Link': 'https://www.redbus.in/bus-tickets/digha-to-barasat-west-bengal', 'Bus Name': 'WBTC (CTC) HABRA-DIGHA via Bally - 26|10:40', 'Bus Type': 'Non AC Seater (2+3)', 'Departing Time': '10:40', 'Duration': '04h 45m', 'Reaching Time': '15:25', 'Star Rating': '3.7', 'Price': '161', 'Seat Availability': '37 Seats available'}
# {'State': 'Southbengal', 'Route Name': 'Digha to Barasat (West Bengal)', 'Route Link': 'https://www.redbus.in/bus-tickets/digha-to-barasat-west-bengal', 'Bus Name': 'WBTC (CTC) HABRA-DIGHA via Bally - 26|11:30', 'Bus Type': 'Non AC Seater (2+3)', 'Departing Time': '11:30', 'Duration': '04h 45m', 'Reaching Time': '16:15', 'Star Rating': '3.3', 'Price': '161', 'Seat Availability': '47 Seats available'}
# {'State': 'Southbengal', 'Route Name': 'Digha to Barasat (West Bengal)', 'Route Link': 'https://www.redbus.in/bus-tickets/digha-to-barasat-west-bengal', 'Bus Name': 'WBTC (CTC) HABRA-DIGHA via Bally - 26|12:50', 'Bus Type': 'Non AC Seater (2+3)', 'Departing Time': '12:50', 'Duration': '04h 45m', 'Reaching Time': '17:35', 'Star Rating': '3.5', 'Price': '161', 'Seat Availability': '33 Seats available'}
# {'State': 'Southbengal', 'Route Name': 'Digha to Barasat (West Bengal)', 'Route Link': 'https://www.redbus.in/bus-tickets/digha-to-barasat-west-bengal', 'Bus Name': 'WBTC (CTC) HABRA-DIGHA via Bally - 26|14:50', 'Bus Type': 'Non AC Seater (2+3)', 'Departing Time': '14:50', 'Duration': '04h 45m', 'Reaching Time': '19:35', 'Star Rating': '3.6', 'Price': '161', 'Seat Availability': '29 Seats available'}
# {'State': 'Southbengal', 'Route Name': 'Digha to Barasat (West Bengal)', 'Route Link': 'https://www.redbus.in/bus-tickets/digha-to-barasat-west-bengal', 'Bus Name': 'WBTC (CTC) BARASAT-DIGHA via Bally - 38|15:35', 'Bus Type': 'Non AC Seater (2+3)', 'Departing Time': '15:35', 'Duration': '05h 15m', 'Reaching Time': '20:50', 'Star Rating': '3.8', 'Price': '161', 'Seat Availability': '35 Seats available'}
# {'State': 'Southbengal', 'Route Name': 'Digha to Barasat (West Bengal)', 'Route Link': 'https://www.redbus.in/bus-tickets/digha-to-barasat-west-bengal', 'Bus Name': 'SBSTC-DIGHA - HABRA - 13:40 (DIGHA DEPOT) - 522', 'Bus Type': 'Non AC Seater (2+3)', 'Departing Time': '13:40', 'Duration': '05h 30m', 'Reaching Time': '19:10', 'Star Rating': '3.5', 'Price': '170', 'Seat Availability': '51 Seats available'}
# {'State': 'Southbengal', 'Route Name': 'Digha to Barasat (West Bengal)', 'Route Link': 'https://www.redbus.in/bus-tickets/digha-to-barasat-west-bengal', 'Bus Name': 'SBSTC-DIGHA - BARASAT - 14:20 (DIGHA DEPOT) - 516', 'Bus Type': 'Non AC Seater (2+3)', 'Departing Time': '14:20', 'Duration': '05h 00m', 'Reaching Time': '19:20', 'Star Rating': '2.9', 'Price': '170', 'Seat Availability': '52 Seats available'}
# {'State': 'Southbengal', 'Route Name': 'Digha to Barasat (West Bengal)', 'Route Link': 'https://www.redbus.in/bus-tickets/digha-to-barasat-west-bengal', 'Bus Name': 'City Express', 'Bus Type': 'AC Seater (2+3)', 'Departing Time': '11:35', 'Duration': '05h 21m', 'Reaching Time': '16:56', 'Star Rating': '4.0', 'Price': '320', 'Seat Availability': '24 Seats available'}
# {'State': 'Southbengal', 'Route Name': 'Digha to Barasat (West Bengal)', 'Route Link': 'https://www.redbus.in/bus-tickets/digha-to-barasat-west-bengal', 'Bus Name': 'Snemita Paribahan', 'Bus Type': 'AC Seater (2+3)', 'Departing Time': '11:35', 'Duration': '05h 35m', 'Reaching Time': '17:10', 'Star Rating': '3.6', 'Price': '270', 'Seat Availability': '17 Seats available'}
# {'State': 'Southbengal', 'Route Name': 'Digha to Barasat (West Bengal)', 'Route Link': 'https://www.redbus.in/bus-tickets/digha-to-barasat-west-bengal', 'Bus Name': 'Satya Paribahan', 'Bus Type': 'A/C Seater (2+3)', 'Departing Time': '23:00', 'Duration': '06h 10m', 'Reaching Time': '05:10', 'Star Rating': '3.5', 'Price': '270', 'Seat Availability': '28 Seats available'}
# {'State': 'Southbengal', 'Route Name': 'Digha to Barasat (West Bengal)', 'Route Link': 'https://www.redbus.in/bus-tickets/digha-to-barasat-west-bengal', 'Bus Name': 'SANTOSH BUS SERVICE', 'Bus Type': 'A/C Seater / Sleeper (2+2)', 'Departing Time': '13:20', 'Duration': '06h 10m', 'Reaching Time': '19:30', 'Star Rating': '2.5', 'Price': '389', 'Seat Availability': '26 Seats available'}
# Error scraping bus details for Digha to Barasat (West Bengal): Message: no such element: Unable to locate element: {"method":"xpath","selector":".//div[@class='rating-sec lh-24']"}
#   (Session info: chrome=132.0.6834.160); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF6859502F5+28725]
# 	(No symbol) [0x00007FF6858B2AE0]
# 	(No symbol) [0x00007FF68574510A]
# 	(No symbol) [0x00007FF6857993D2]
# 	(No symbol) [0x00007FF6857995FC]
# 	(No symbol) [0x00007FF68578C0BC]
# 	(No symbol) [0x00007FF6857BFFEF]
# 	(No symbol) [0x00007FF68578BF86]
# 	(No symbol) [0x00007FF6857C01C0]
# 	(No symbol) [0x00007FF6857E0181]
# 	(No symbol) [0x00007FF6857BFD53]
# 	(No symbol) [0x00007FF68578A0E3]
# 	(No symbol) [0x00007FF68578B471]
# 	GetHandleVerifier [0x00007FF685C7F30D+3366989]
# 	GetHandleVerifier [0x00007FF685C912F0+3440688]
# 	GetHandleVerifier [0x00007FF685C878FD+3401277]
# 	GetHandleVerifier [0x00007FF685A1AAAB+858091]
# 	(No symbol) [0x00007FF6858BE74F]
# 	(No symbol) [0x00007FF6858BA304]
# 	(No symbol) [0x00007FF6858BA49D]
# 	(No symbol) [0x00007FF6858A8B69]
# 	BaseThreadInitThunk [0x00007FFFFD2CE8D7+23]
# 	RtlUserThreadStart [0x00007FFFFE93FBCC+44]
#
# Error scraping bus details for Digha to Barasat (West Bengal): Message: no such element: Unable to locate element: {"method":"xpath","selector":".//div[@class='rating-sec lh-24']"}
#   (Session info: chrome=132.0.6834.160); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF6859502F5+28725]
# 	(No symbol) [0x00007FF6858B2AE0]
# 	(No symbol) [0x00007FF68574510A]
# 	(No symbol) [0x00007FF6857993D2]
# 	(No symbol) [0x00007FF6857995FC]
# 	(No symbol) [0x00007FF68578C0BC]
# 	(No symbol) [0x00007FF6857BFFEF]
# 	(No symbol) [0x00007FF68578BF86]
# 	(No symbol) [0x00007FF6857C01C0]
# 	(No symbol) [0x00007FF6857E0181]
# 	(No symbol) [0x00007FF6857BFD53]
# 	(No symbol) [0x00007FF68578A0E3]
# 	(No symbol) [0x00007FF68578B471]
# 	GetHandleVerifier [0x00007FF685C7F30D+3366989]
# 	GetHandleVerifier [0x00007FF685C912F0+3440688]
# 	GetHandleVerifier [0x00007FF685C878FD+3401277]
# 	GetHandleVerifier [0x00007FF685A1AAAB+858091]
# 	(No symbol) [0x00007FF6858BE74F]
# 	(No symbol) [0x00007FF6858BA304]
# 	(No symbol) [0x00007FF6858BA49D]
# 	(No symbol) [0x00007FF6858A8B69]
# 	BaseThreadInitThunk [0x00007FFFFD2CE8D7+23]
# 	RtlUserThreadStart [0x00007FFFFE93FBCC+44]
#
# Error clicking 'View Buses' button for Durgapur (West Bengal) to Jhargram: Message:
#
# {'State': 'Southbengal', 'Route Name': 'Durgapur (West Bengal) to Jhargram', 'Route Link': 'https://www.redbus.in/bus-tickets/durgapur-to-jhargram', 'Bus Name': 'SBSTC-DURGAPUR - JHARGRAM - 10:45 (JHR DEPOT) - 3634', 'Bus Type': 'Non AC Seater (2+3)', 'Departing Time': '10:45', 'Duration': '13h 15m', 'Reaching Time': '00:00', 'Star Rating': '3.9', 'Price': '145', 'Seat Availability': '43 Seats available'}
# {'State': 'Southbengal', 'Route Name': 'Durgapur (West Bengal) to Jhargram', 'Route Link': 'https://www.redbus.in/bus-tickets/durgapur-to-jhargram', 'Bus Name': 'SBSTC-DURGAPUR - ROHINI - 12:40 (KULTEKRY) DGP DEPOT - 1376', 'Bus Type': 'Non AC Seater (2+3)', 'Departing Time': '12:40', 'Duration': '11h 20m', 'Reaching Time': '00:00', 'Star Rating': '4.5', 'Price': '145', 'Seat Availability': '48 Seats available'}
# {'State': 'Southbengal', 'Route Name': 'Durgapur (West Bengal) to Jhargram', 'Route Link': 'https://www.redbus.in/bus-tickets/durgapur-to-jhargram', 'Bus Name': 'SBSTC-DURGAPUR - JHARGRAM - 13:30 (DGP DEPOT) - 3965', 'Bus Type': 'Non AC Seater (2+3)', 'Departing Time': '14:00', 'Duration': '10h 00m', 'Reaching Time': '00:00', 'Star Rating': '4.3', 'Price': '141', 'Seat Availability': '51 Seats available'}
# Collected Bus Details: [{'State': 'Southbengal', 'Route Name': 'Kolkata to Asansol (West Bengal)', 'Route Link': 'https://www.redbus.in/bus-tickets/kolkata-to-asansol', 'Bus Name': 'SBSTC-KOLKATA - ASANSOL - 10:30 (HOWRAH DEPOT) - 763', 'Bus Type': 'Non AC Seater (2+3)', 'Departing Time': '10:30', 'Duration': '04h 30m', 'Reaching Time': '15:00', 'Star Rating': '2.5', 'Price': '180', 'Seat Availability': '51 Seats available'}, {'State': 'Southbengal', 'Route Name': 'Kolkata to Asansol (West Bengal)', 'Route Link': 'https://www.redbus.in/bus-tickets/kolkata-to-asansol', 'Bus Name': 'SBSTC-KOLKATA - ASANSOL - 10:45 (ASN DEPOT) - 449', 'Bus Type': 'Non AC Seater (2+3)', 'Departing Time': '10:45', 'Duration': '04h 15m', 'Reaching Time': '15:00', 'Star Rating': '3.3', 'Price': '180', 'Seat Availability': '52 Seats available'}, {'State': 'Southbengal', 'Route Name': 'Kolkata to Asansol (West Bengal)', 'Route Link': 'https://www.redbus.in/bus-tickets/kolkata-to-asansol', 'Bus Name': 'SBSTC-KOLKATA - PURULIA - VIA - ASN - 11:00 (HWH DEPOT) - 2681', 'Bus Type': 'Non AC Seater (2+3)', 'Departing Time': '11:00', 'Duration': '04h 30m', 'Reaching Time': '15:30', 'Star Rating': '3.5', 'Price': '180', 'Seat Availability': '49 Seats available'}, {'State': 'Southbengal', 'Route Name': 'Kolkata to Asansol (West Bengal)', 'Route Link': 'https://www.redbus.in/bus-tickets/kolkata-to-asansol', 'Bus Name': 'SBSTC-KOLKATA - ASANSOL - 11:40 (ASANSOL DEPOT) - 250', 'Bus Type': 'Non AC Seater (2+3)', 'Departing Time': '11:40', 'Duration': '04h 30m', 'Reaching Time': '16:10', 'Star Rating': '3.8', 'Price': '180', 'Seat Availability': '52 Seats available'}, {'State': 'Southbengal', 'Route Name': 'Kolkata to Asansol (West Bengal)', 'Route Link': 'https://www.redbus.in/bus-tickets/kolkata-to-asansol', 'Bus Name': 'SBSTC-KOLKATA - ASANSOL - L/S - 12:30 (ASANSOL DEPOT) - 252', 'Bus Type': 'Non AC Seater (2+3)', 'Departing Time': '12:30', 'Duration': '04h 30m', 'Reaching Time': '17:00', 'Star Rating': '3.0', 'Price': '180', 'Seat Availability': '51 Seats available'}, {'State': 'Southbengal', 'Route Name': 'Kolkata to Asansol (West Bengal)', 'Route Link': 'https://www.redbus.in/bus-tickets/kolkata-to-asansol', 'Bus Name': 'WBTC (CTC) KOLKATA - ASANSOL - PURULIA (AC VOLVO) Banglashree Express - 133|13:45', 'Bus Type': 'Volvo AC Seater (2+2)', 'Departing Time': '13:45', 'Duration': '03h 55m', 'Reaching Time': '17:40', 'Star Rating': '3.3', 'Price': '430', 'Seat Availability': '25 Seats available'}, {'State': 'Southbengal', 'Route Name': 'Kolkata to Asansol (West Bengal)', 'Route Link': 'https://www.redbus.in/bus-tickets/kolkata-to-asansol', 'Bus Name': 'SHYAMOLI Pvt. Ltd.(Karunamoyee)', 'Bus Type': 'Scania Multi-Axle AC Semi Sleeper (2+2)', 'Departing Time': '10:00', 'Duration': '05h 00m', 'Reaching Time': '15:00', 'Star Rating': '4.3', 'Price': '529', 'Seat Availability': '9 Seats available'}, {'State': 'Southbengal', 'Route Name': 'Kolkata to Asansol (West Bengal)', 'Route Link': 'https://www.redbus.in/bus-tickets/kolkata-to-asansol', 'Bus Name': 'SHYAMOLI Pvt. Ltd.(Karunamoyee)', 'Bus Type': 'Scania Multi-Axle AC Semi Sleeper (2+2)', 'Departing Time': '10:00', 'Duration': '05h 00m', 'Reaching Time': '15:00', 'Star Rating': '3.8', 'Price': '524', 'Seat Availability': '7 Seats available'}, {'State': 'Southbengal', 'Route Name': 'Kolkata to Asansol (West Bengal)', 'Route Link': 'https://www.redbus.in/bus-tickets/kolkata-to-asansol', 'Bus Name': 'Shyamoli Paribahan Pvt Ltd', 'Bus Type': 'Volvo A/C Seater (2+2)', 'Departing Time': '10:05', 'Duration': '04h 10m', 'Reaching Time': '14:15', 'Star Rating': '4.1', 'Price': '524', 'Seat Availability': '15 Seats available'}, {'State': 'Southbengal', 'Route Name': 'Kolkata to Asansol (West Bengal)', 'Route Link': 'https://www.redbus.in/bus-tickets/kolkata-to-asansol', 'Bus Name': 'Express Line', 'Bus Type': 'Volvo 9600 A/C Seater (2+2)', 'Departing Time': '10:25', 'Duration': '05h 00m', 'Reaching Time': '15:25', 'Star Ratin ...
