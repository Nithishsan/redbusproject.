# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver import ActionChains
import time
import mysql.connector
import pandas as pd
# Connect Database
db_connection = mysql.connector.connect(
    host="localhost",
    user="root",
    password="1234",
    database="redbus"
)
cursor = db_connection.cursor()
print("Database connected Successfully")

# SQL to create table
create_table_query = """
CREATE TABLE IF NOT EXISTS BusDetails(
    id INT PRIMARY KEY AUTO_INCREMENT,
    state VARCHAR(100) DEFAULT 'Andhra Pradesh',
    route_name VARCHAR(255),
    route_link VARCHAR(255),
    bus_name VARCHAR(255),
    bus_type VARCHAR(255),
    departing_time TEXT,
    duration VARCHAR(50),
    reaching_time TEXT,
    star_rating TEXT,
    price VARCHAR(50),
    seat_availability TEXT
);
"""
cursor.execute(create_table_query)
print("Table created successfully")

# Initialize the WebDriver
driver = webdriver.Chrome()
driver.implicitly_wait(5)
wait = WebDriverWait(driver, 10)

# Navigate to the upsrtc Bus Routes page
driver.get("https://www.redbus.in/online-booking/chandigarh-transport-undertaking-ctu")
driver.maximize_window()
time.sleep(2)
route_data = []
# Function to scrape route data
def scrape_page():
    routescontainer = wait.until(EC.presence_of_all_elements_located((By.XPATH, '//*[@id="root"]/div/div[4]/div[2]/div[1]/a')))
      
    for route in routescontainer:
        route_data.append({
            'Route Name': route.text,
            'Route Link': route.get_attribute('href')
        })
    return route_data  # Return the scraped data

# Pagination to collect routes from multiple pages
for page_number in range(1, 6):
    try:
        pagination_container = wait.until(EC.presence_of_element_located((By.XPATH, '//*[@id="root"]/div/div[4]/div[12]')))
        next_page_button = pagination_container.find_element(By.XPATH, f'.//div[contains(@class,"DC_117_pageTabs") and text()="{page_number + 1}"]')

        actions = ActionChains(driver)
        actions.move_to_element(next_page_button).perform()
        next_page_button.click()
        time.sleep(1)

        wait.until(EC.text_to_be_present_in_element((By.XPATH, f'.//div[contains(@class,"DC_117_pageTabs DC_117_pageActive")]'), str(page_number + 1)))
        time.sleep(2)

        scrape_page()

    except Exception as e:
        print(e)
        break


# Function to scrape bus details
def collect_bus_details():
    alldetails = []
    for data in route_data:
        link = data['Route Link']
        route_name = data['Route Name']
        try:
            driver.get(link)
            time.sleep(2)
            try:
                view_buses_buttons = wait.until(EC.presence_of_all_elements_located((By.XPATH, "//div[@class='button']")))
                for button in view_buses_buttons:
                    wait.until(EC.element_to_be_clickable(button)).click()
                    time.sleep(3)  # Wait for the buses to load
            except Exception as e:
                print(f"Error clicking 'View Buses' button for {route_name}: {e}")

            bus_containers = wait.until(EC.presence_of_all_elements_located((By.XPATH, "//div[contains(@class, 'clearfix bus-item')]")))
            for bus_container in bus_containers:
                try:
                    busname = bus_container.find_element(By.XPATH, ".//div[@class='travels lh-24 f-bold d-color']").text
                    bustype = bus_container.find_element(By.XPATH, ".//div[@class='bus-type f-12 m-top-16 l-color evBus']").text
                    departuretiming = bus_container.find_element(By.XPATH, ".//div[@class='dp-time f-19 d-color f-bold']").text
                    duration = bus_container.find_element(By.XPATH, ".//div[@class='dur l-color lh-24']").text
                    reachtiming = bus_container.find_element(By.XPATH, ".//div[@class='bp-time f-19 d-color disp-Inline']").text
                    rating = bus_container.find_element(By.XPATH, ".//div[@class='rating-sec lh-24']").text
                    price = bus_container.find_element(By.XPATH, ".//span[contains(@class,'f-19 f-bold') or contains(@class,'f-bold f-19')]").text
                    seat = bus_container.find_element(By.XPATH, ".//div[contains(@class, 'seat-left m-top-30') or contains(@class,'seat-left m-top-16')]").text

                    details = {
                        'State': "Chandigarh",
                        'Route Name': route_name,
                        'Route Link': link,
                        'Bus Name': busname,
                        'Bus Type': bustype,
                        'Departing Time': departuretiming,
                        'Duration': duration,
                        'Reaching Time': reachtiming,
                        'Star Rating': rating,
                        'Price': price,
                        'Seat Availability': seat,
                    }
                    # Check if the details already exist in the list
                    if details not in alldetails:
                        print(details)
                        alldetails.append(details)

                        # Insert data into the database
                        insert_query = """
                        INSERT IGNORE INTO BusDetails (state, route_name, route_link, bus_name, bus_type, departing_time, duration, reaching_time, star_rating, price, seat_availability)
                        VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
                        """
                        cursor.execute(insert_query, (
                            details['State'],
                            details['Route Name'],
                            details['Route Link'],
                            details['Bus Name'],
                            details['Bus Type'],
                            details['Departing Time'],
                            details['Duration'],
                            details['Reaching Time'],
                            details['Star Rating'],
                            details['Price'],
                            details['Seat Availability']
                        ))
                        db_connection.commit()
                except Exception as e:
                    print(f"Error scraping bus details for {route_name}: {e}")
        except Exception as e:
            print(f"Error accessing route link {link}: {e}")
    return alldetails

# Main execution


bus_details = collect_bus_details()
print("Collected Bus Details:", bus_details)


df = pd.DataFrame(bus_details)
df.to_csv("Chandigarh.csv", index=False)

# Close the WebDriver
driver.quit()

# Close the Database Connection
cursor.close()
db_connection.close()
# Out:
# Database connected Successfully
# Table created successfully
# Message:
# Stacktrace:
# 	GetHandleVerifier [0x00007FF6859502F5+28725]
# 	(No symbol) [0x00007FF6858B2AE0]
# 	(No symbol) [0x00007FF68574510A]
# 	(No symbol) [0x00007FF6857993D2]
# 	(No symbol) [0x00007FF6857995FC]
# 	(No symbol) [0x00007FF6857E3407]
# 	(No symbol) [0x00007FF6857BFFEF]
# 	(No symbol) [0x00007FF6857E0181]
# 	(No symbol) [0x00007FF6857BFD53]
# 	(No symbol) [0x00007FF68578A0E3]
# 	(No symbol) [0x00007FF68578B471]
# 	GetHandleVerifier [0x00007FF685C7F30D+3366989]
# 	GetHandleVerifier [0x00007FF685C912F0+3440688]
# 	GetHandleVerifier [0x00007FF685C878FD+3401277]
# 	GetHandleVerifier [0x00007FF685A1AAAB+858091]
# 	(No symbol) [0x00007FF6858BE74F]
# 	(No symbol) [0x00007FF6858BA304]
# 	(No symbol) [0x00007FF6858BA49D]
# 	(No symbol) [0x00007FF6858A8B69]
# 	BaseThreadInitThunk [0x00007FFFFD2CE8D7+23]
# 	RtlUserThreadStart [0x00007FFFFE93FBCC+44]
#
# Error clicking 'View Buses' button for Shimla to Chandigarh: Message: element click intercepted: Element <div class="button">...</div> is not clickable at point (1442, 709). Other element would receive the click: <div class="clearfix bus-item  ">...</div>
#   (Session info: chrome=132.0.6834.160)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF6859502F5+28725]
# 	(No symbol) [0x00007FF6858B2AE0]
# 	(No symbol) [0x00007FF68574510A]
# 	(No symbol) [0x00007FF6857A10F8]
# 	(No symbol) [0x00007FF68579EB42]
# 	(No symbol) [0x00007FF68579BC51]
# 	(No symbol) [0x00007FF68579ABB1]
# 	(No symbol) [0x00007FF68578C6B4]
# 	(No symbol) [0x00007FF6857BFFAA]
# 	(No symbol) [0x00007FF68578BF86]
# 	(No symbol) [0x00007FF6857C01C0]
# 	(No symbol) [0x00007FF6857E0181]
# 	(No symbol) [0x00007FF6857BFD53]
# 	(No symbol) [0x00007FF68578A0E3]
# 	(No symbol) [0x00007FF68578B471]
# 	GetHandleVerifier [0x00007FF685C7F30D+3366989]
# 	GetHandleVerifier [0x00007FF685C912F0+3440688]
# 	GetHandleVerifier [0x00007FF685C878FD+3401277]
# 	GetHandleVerifier [0x00007FF685A1AAAB+858091]
# 	(No symbol) [0x00007FF6858BE74F]
# 	(No symbol) [0x00007FF6858BA304]
# 	(No symbol) [0x00007FF6858BA49D]
# 	(No symbol) [0x00007FF6858A8B69]
# 	BaseThreadInitThunk [0x00007FFFFD2CE8D7+23]
# 	RtlUserThreadStart [0x00007FFFFE93FBCC+44]
#
# {'State': 'Chandigarh', 'Route Name': 'Shimla to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/shimla-to-chandigarh', 'Bus Name': 'HRTC - 1190', 'Bus Type': 'Ordinary 3+2 Non AC Seater', 'Departing Time': '10:54', 'Duration': '04h 06m', 'Reaching Time': '15:00', 'Star Rating': '3.9', 'Price': '242', 'Seat Availability': '37 Seats available'}
# {'State': 'Chandigarh', 'Route Name': 'Shimla to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/shimla-to-chandigarh', 'Bus Name': 'HRTC - 152', 'Bus Type': 'Ordinary 3+2 Non AC Seater', 'Departing Time': '11:00', 'Duration': '04h 40m', 'Reaching Time': '15:40', 'Star Rating': '3.9', 'Price': '242', 'Seat Availability': '27 Seats available'}
# {'State': 'Chandigarh', 'Route Name': 'Shimla to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/shimla-to-chandigarh', 'Bus Name': 'HRTC - 150', 'Bus Type': 'Ordinary 3+2 Non AC Seater', 'Departing Time': '11:12', 'Duration': '03h 48m', 'Reaching Time': '15:00', 'Star Rating': '3.9', 'Price': '242', 'Seat Availability': '27 Seats available'}
# {'State': 'Chandigarh', 'Route Name': 'Shimla to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/shimla-to-chandigarh', 'Bus Name': 'HRTC - 2', 'Bus Type': 'Himsuta AC Seater Volvo/Scania 2+2', 'Departing Time': '11:15', 'Duration': '03h 15m', 'Reaching Time': '14:30', 'Star Rating': '3.8', 'Price': '389', 'Seat Availability': '18 Seats available'}
# {'State': 'Chandigarh', 'Route Name': 'Shimla to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/shimla-to-chandigarh', 'Bus Name': 'HRTC - 47', 'Bus Type': 'Himsuta AC Seater Volvo/Scania 2+2', 'Departing Time': '12:25', 'Duration': '03h 45m', 'Reaching Time': '16:10', 'Star Rating': '4.5', 'Price': '389', 'Seat Availability': '34 Seats available'}
# {'State': 'Chandigarh', 'Route Name': 'Shimla to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/shimla-to-chandigarh', 'Bus Name': 'HRTC - 174', 'Bus Type': 'Ordinary 3+2 Non AC Seater', 'Departing Time': '12:36', 'Duration': '03h 39m', 'Reaching Time': '16:15', 'Star Rating': '2.7', 'Price': '242', 'Seat Availability': '27 Seats available'}
# {'State': 'Chandigarh', 'Route Name': 'Shimla to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/shimla-to-chandigarh', 'Bus Name': 'HRTC - 1609', 'Bus Type': 'Ordinary 3+2 Non AC Seater', 'Departing Time': '13:14', 'Duration': '05h 01m', 'Reaching Time': '18:15', 'Star Rating': '3.9', 'Price': '242', 'Seat Availability': '37 Seats available'}
# {'State': 'Chandigarh', 'Route Name': 'Shimla to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/shimla-to-chandigarh', 'Bus Name': 'HRTC - 131', 'Bus Type': 'Ordinary 3+2 Non AC Seater', 'Departing Time': '14:42', 'Duration': '04h 28m', 'Reaching Time': '19:10', 'Star Rating': '3.9', 'Price': '242', 'Seat Availability': '37 Seats available'}
# {'State': 'Chandigarh', 'Route Name': 'Shimla to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/shimla-to-chandigarh', 'Bus Name': 'HRTC - 277', 'Bus Type': 'Ordinary 3+2 Non AC Seater', 'Departing Time': '15:45', 'Duration': '05h 45m', 'Reaching Time': '21:30', 'Star Rating': '3.9', 'Price': '242', 'Seat Availability': '37 Seats available'}
# {'State': 'Chandigarh', 'Route Name': 'Shimla to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/shimla-to-chandigarh', 'Bus Name': 'HRTC - 1707', 'Bus Type': 'Ordinary 3+2 Non AC Seater', 'Departing Time': '16:28', 'Duration': '04h 02m', 'Reaching Time': '20:30', 'Star Rating': '3.3', 'Price': '242', 'Seat Availability': '27 Seats available'}
# {'State': 'Chandigarh', 'Route Name': 'Shimla to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/shimla-to-chandigarh', 'Bus Name': 'HRTC - 227', 'Bus Type': 'Ordinary 3+2 Non AC Seater', 'Departing Time': '17:36', 'Duration': '04h 24m', 'Reaching Time': '22:00', 'Star Rating': '3.9', 'Price': '242', 'Seat Availability': '37 Seats available'}
# {'State': 'Chandigarh', 'Route Name': 'Shimla to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/shimla-to-chandigarh', 'Bus Name': 'HRTC - 104', 'Bus Type': 'A/C Executive (2+3)', 'Departing Time': '18:20', 'Duration': '03h 01m', 'Reaching Time': '21:21', 'Star Rating': '3.1', 'Price': '257', 'Seat Availability': '40 Seats available'}
# {'State': 'Chandigarh', 'Route Name': 'Shimla to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/shimla-to-chandigarh', 'Bus Name': 'HRTC - 188', 'Bus Type': 'Ordinary 3+2 Non AC Seater', 'Departing Time': '19:25', 'Duration': '03h 01m', 'Reaching Time': '22:26', 'Star Rating': '3.9', 'Price': '242', 'Seat Availability': '37 Seats available'}
# {'State': 'Chandigarh', 'Route Name': 'Shimla to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/shimla-to-chandigarh', 'Bus Name': 'HRTC - 1711', 'Bus Type': 'Ordinary 3+2 Non AC Seater', 'Departing Time': '20:00', 'Duration': '03h 00m', 'Reaching Time': '23:00', 'Star Rating': '3.9', 'Price': '242', 'Seat Availability': '37 Seats available'}
# {'State': 'Chandigarh', 'Route Name': 'Shimla to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/shimla-to-chandigarh', 'Bus Name': 'HRTC - 74', 'Bus Type': 'Himsuta AC Seater Volvo/Scania 2+2', 'Departing Time': '20:00', 'Duration': '02h 45m', 'Reaching Time': '22:45', 'Star Rating': '3.9', 'Price': '389', 'Seat Availability': '11 Seats available'}
# {'State': 'Chandigarh', 'Route Name': 'Shimla to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/shimla-to-chandigarh', 'Bus Name': 'RSRTC - 192348', 'Bus Type': 'Super Luxury Volvo AC Seater Pushback 2+2', 'Departing Time': '16:30', 'Duration': '04h 45m', 'Reaching Time': '21:15', 'Star Rating': '4.2', 'Price': '432', 'Seat Availability': '29 Seats available'}
# {'State': 'Chandigarh', 'Route Name': 'Shimla to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/shimla-to-chandigarh', 'Bus Name': 'Laxmi holidays', 'Bus Type': 'Scania Multi-Axle AC Semi Sleeper (2+2)', 'Departing Time': '09:30', 'Duration': '03h 10m', 'Reaching Time': '12:40', 'Star Rating': '4.6', 'Price': '549', 'Seat Availability': '16 Seats available'}
# {'State': 'Chandigarh', 'Route Name': 'Shimla to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/shimla-to-chandigarh', 'Bus Name': 'Laxmi holidays', 'Bus Type': 'Volvo A/C Semi Sleeper (2+2)', 'Departing Time': '10:30', 'Duration': '03h 10m', 'Reaching Time': '13:40', 'Star Rating': '4.7', 'Price': '499', 'Seat Availability': '15 Seats available'}
# {'State': 'Chandigarh', 'Route Name': 'Shimla to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/shimla-to-chandigarh', 'Bus Name': 'City Land Travels', 'Bus Type': 'Volvo A/C Semi Sleeper (2+2)', 'Departing Time': '10:30', 'Duration': '03h 05m', 'Reaching Time': '13:35', 'Star Rating': '4.0', 'Price': '450', 'Seat Availability': '28 Seats available'}
# {'State': 'Chandigarh', 'Route Name': 'Shimla to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/shimla-to-chandigarh', 'Bus Name': 'Laxmi holidays', 'Bus Type': 'Volvo A/C Semi Sleeper (2+2)', 'Departing Time': '10:30', 'Duration': '02h 30m', 'Reaching Time': '13:00', 'Star Rating': '4.8', 'Price': '499', 'Seat Availability': '16 Seats available'}
# {'State': 'Chandigarh', 'Route Name': 'Sujanpur (himachal pradesh) to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/sujanpur-to-chandigarh', 'Bus Name': 'HRTC - 6668', 'Bus Type': 'Ordinary 3+2 Non AC Seater', 'Departing Time': '11:30', 'Duration': '06h 30m', 'Reaching Time': '18:00', 'Star Rating': '3.9', 'Price': '381', 'Seat Availability': '37 Seats available'}
# {'State': 'Chandigarh', 'Route Name': 'Sujanpur (himachal pradesh) to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/sujanpur-to-chandigarh', 'Bus Name': 'HRTC - 955', 'Bus Type': 'Ordinary 3+2 Non AC Seater', 'Departing Time': '16:20', 'Duration': '07h 35m', 'Reaching Time': '23:55', 'Star Rating': '3.9', 'Price': '386', 'Seat Availability': '37 Seats available'}
# {'State': 'Chandigarh', 'Route Name': 'Sujanpur (himachal pradesh) to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/sujanpur-to-chandigarh', 'Bus Name': 'HRTC - 1146', 'Bus Type': 'Ordinary 3+2 Non AC Seater', 'Departing Time': '17:10', 'Duration': '06h 03m', 'Reaching Time': '23:13', 'Star Rating': '3.9', 'Price': '383', 'Seat Availability': '37 Seats available'}
# {'State': 'Chandigarh', 'Route Name': 'Sujanpur (himachal pradesh) to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/sujanpur-to-chandigarh', 'Bus Name': 'HRTC - 952', 'Bus Type': 'Ordinary 3+2 Non AC Seater', 'Departing Time': '17:34', 'Duration': '06h 46m', 'Reaching Time': '00:20', 'Star Rating': '3.9', 'Price': '383', 'Seat Availability': '37 Seats available'}
# {'State': 'Chandigarh', 'Route Name': 'Sujanpur (himachal pradesh) to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/sujanpur-to-chandigarh', 'Bus Name': 'HRTC - 953', 'Bus Type': 'Ordinary 3+2 Non AC Seater', 'Departing Time': '18:20', 'Duration': '05h 30m', 'Reaching Time': '23:50', 'Star Rating': '3.9', 'Price': '373', 'Seat Availability': '34 Seats available'}
# {'State': 'Chandigarh', 'Route Name': 'Sujanpur (himachal pradesh) to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/sujanpur-to-chandigarh', 'Bus Name': 'Chandigarh Transport Undertaking (CTU) - 165837', 'Bus Type': 'HVAC Seater (2+3)', 'Departing Time': '13:20', 'Duration': '06h 30m', 'Reaching Time': '19:50', 'Star Rating': '4.2', 'Price': '476.2', 'Seat Availability': '42 Seats available'}
# {'State': 'Chandigarh', 'Route Name': 'Sujanpur (himachal pradesh) to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/sujanpur-to-chandigarh', 'Bus Name': 'Laxmi holidays', 'Bus Type': 'Volvo A/C Semi Sleeper (2+2)', 'Departing Time': '19:30', 'Duration': '05h 00m', 'Reaching Time': '00:30', 'Star Rating': '5.0', 'Price': '599', 'Seat Availability': '30 Seats available'}
# {'State': 'Chandigarh', 'Route Name': 'Sujanpur (himachal pradesh) to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/sujanpur-to-chandigarh', 'Bus Name': 'Himalayan Nomad Ktc', 'Bus Type': 'Volvo A/C Semi Sleeper (2+2)', 'Departing Time': '21:15', 'Duration': '04h 15m', 'Reaching Time': '01:30', 'Star Rating': '4.0', 'Price': '516', 'Seat Availability': '4 Seats available'}
# {'State': 'Chandigarh', 'Route Name': 'Sujanpur (himachal pradesh) to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/sujanpur-to-chandigarh', 'Bus Name': 'Laxmi holidays', 'Bus Type': 'Volvo A/C Semi Sleeper (2+2)', 'Departing Time': '21:30', 'Duration': '05h 10m', 'Reaching Time': '02:40', 'Star Rating': '5.0', 'Price': '699', 'Seat Availability': '41 Seats available'}
# {'State': 'Chandigarh', 'Route Name': 'Sujanpur (himachal pradesh) to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/sujanpur-to-chandigarh', 'Bus Name': 'Himalayan Nomad Ktc', 'Bus Type': 'Volvo A/C Semi Sleeper (2+2)', 'Departing Time': '21:30', 'Duration': '04h 15m', 'Reaching Time': '01:45', 'Star Rating': '4.0', 'Price': '586', 'Seat Availability': '13 Seats available'}
# Collected Bus Details: [{'State': 'Chandigarh', 'Route Name': 'Shimla to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/shimla-to-chandigarh', 'Bus Name': 'HRTC - 1190', 'Bus Type': 'Ordinary 3+2 Non AC Seater', 'Departing Time': '10:54', 'Duration': '04h 06m', 'Reaching Time': '15:00', 'Star Rating': '3.9', 'Price': '242', 'Seat Availability': '37 Seats available'}, {'State': 'Chandigarh', 'Route Name': 'Shimla to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/shimla-to-chandigarh', 'Bus Name': 'HRTC - 152', 'Bus Type': 'Ordinary 3+2 Non AC Seater', 'Departing Time': '11:00', 'Duration': '04h 40m', 'Reaching Time': '15:40', 'Star Rating': '3.9', 'Price': '242', 'Seat Availability': '27 Seats available'}, {'State': 'Chandigarh', 'Route Name': 'Shimla to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/shimla-to-chandigarh', 'Bus Name': 'HRTC - 150', 'Bus Type': 'Ordinary 3+2 Non AC Seater', 'Departing Time': '11:12', 'Duration': '03h 48m', 'Reaching Time': '15:00', 'Star Rating': '3.9', 'Price': '242', 'Seat Availability': '27 Seats available'}, {'State': 'Chandigarh', 'Route Name': 'Shimla to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/shimla-to-chandigarh', 'Bus Name': 'HRTC - 2', 'Bus Type': 'Himsuta AC Seater Volvo/Scania 2+2', 'Departing Time': '11:15', 'Duration': '03h 15m', 'Reaching Time': '14:30', 'Star Rating': '3.8', 'Price': '389', 'Seat Availability': '18 Seats available'}, {'State': 'Chandigarh', 'Route Name': 'Shimla to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/shimla-to-chandigarh', 'Bus Name': 'HRTC - 47', 'Bus Type': 'Himsuta AC Seater Volvo/Scania 2+2', 'Departing Time': '12:25', 'Duration': '03h 45m', 'Reaching Time': '16:10', 'Star Rating': '4.5', 'Price': '389', 'Seat Availability': '34 Seats available'}, {'State': 'Chandigarh', 'Route Name': 'Shimla to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/shimla-to-chandigarh', 'Bus Name': 'HRTC - 174', 'Bus Type': 'Ordinary 3+2 Non AC Seater', 'Departing Time': '12:36', 'Duration': '03h 39m', 'Reaching Time': '16:15', 'Star Rating': '2.7', 'Price': '242', 'Seat Availability': '27 Seats available'}, {'State': 'Chandigarh', 'Route Name': 'Shimla to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/shimla-to-chandigarh', 'Bus Name': 'HRTC - 1609', 'Bus Type': 'Ordinary 3+2 Non AC Seater', 'Departing Time': '13:14', 'Duration': '05h 01m', 'Reaching Time': '18:15', 'Star Rating': '3.9', 'Price': '242', 'Seat Availability': '37 Seats available'}, {'State': 'Chandigarh', 'Route Name': 'Shimla to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/shimla-to-chandigarh', 'Bus Name': 'HRTC - 131', 'Bus Type': 'Ordinary 3+2 Non AC Seater', 'Departing Time': '14:42', 'Duration': '04h 28m', 'Reaching Time': '19:10', 'Star Rating': '3.9', 'Price': '242', 'Seat Availability': '37 Seats available'}, {'State': 'Chandigarh', 'Route Name': 'Shimla to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/shimla-to-chandigarh', 'Bus Name': 'HRTC - 277', 'Bus Type': 'Ordinary 3+2 Non AC Seater', 'Departing Time': '15:45', 'Duration': '05h 45m', 'Reaching Time': '21:30', 'Star Rating': '3.9', 'Price': '242', 'Seat Availability': '37 Seats available'}, {'State': 'Chandigarh', 'Route Name': 'Shimla to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/shimla-to-chandigarh', 'Bus Name': 'HRTC - 1707', 'Bus Type': 'Ordinary 3+2 Non AC Seater', 'Departing Time': '16:28', 'Duration': '04h 02m', 'Reaching Time': '20:30', 'Star Rating': '3.3', 'Price': '242', 'Seat Availability': '27 Seats available'}, {'State': 'Chandigarh', 'Route Name': 'Shimla to Chandigarh', 'Route Link': 'https://www.redbus.in/bus-tickets/shimla-to-chandigarh', 'Bus Name': 'HRTC - 227', 'Bus Type': 'Ordinary 3+2 Non AC Seater', 'Departing Time': '17:36', 'Duration': '04h 24m', 'Reaching Time': '22:00', 'Star Rating': '3.9', 'Price': '242', 'Seat Availability': '37 Seats available'},  ...
